# %%
from PIL import Image
import requests
from io import BytesIO
import matplotlib.pyplot as plt
# %matplotlib inline

response = requests.get('https://sun9-14.userapi.com/impg/RUuRMAAf5R0dQpuluZLnzOAcfyn3jpwxRN2xIQ/huXt5Dq3_mg.jpg?size=1080x1080&quality=96&sign=86dc490a1cc4cc65967e17d3d06a4c37&type=album')
img = Image.open(BytesIO(response.content))

plt.imshow(img)
